# %%
import os
import time
import joblib
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, roc_auc_score

# %%
# Cargar datos (asume df con columnas: 'ID','Category','clean_resume' o 'Resume_str')
df = pd.read_csv("resume_clean.csv")  # o el csv que tengas
df = df.dropna(subset=['Category'])   # asegurar etiquetas
texts = df['clean_resume'].fillna(df['Resume_str']).astype(str)  # preferencia por clean_resume
labels = df['Category'].astype(str)

# Encode labels
le = LabelEncoder()
y = le.fit_transform(labels)
class_names = le.classes_
n_classes = len(class_names)
print("Clases:", n_classes, class_names)

# Stratified split: train (70), val (15), test (15)
X_temp, X_test, y_temp, y_test = train_test_split(texts, y, test_size=0.15, stratify=y, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.17647, stratify=y_temp, random_state=42)
# note: 0.17647 * 0.85 ≈ 0.15 -> yields 70/15/15

print("Tamaños: train", len(X_train), "val", len(X_val), "test", len(X_test))
# Out:
# Clases: 24 ['ACCOUNTANT' 'ADVOCATE' 'AGRICULTURE' 'APPAREL' 'ARTS' 'AUTOMOBILE'
#  'AVIATION' 'BANKING' 'BPO' 'BUSINESS-DEVELOPMENT' 'CHEF' 'CONSTRUCTION'
#  'CONSULTANT' 'DESIGNER' 'DIGITAL-MEDIA' 'ENGINEERING' 'FINANCE' 'FITNESS'
#  'HEALTHCARE' 'HR' 'INFORMATION-TECHNOLOGY' 'PUBLIC-RELATIONS' 'SALES'
#  'TEACHER']
# Tamaños: train 1738 val 373 test 373

# %%
def classification_report_multi(y_true, y_pred, labels=None, average='macro'):
    acc = accuracy_score(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average=average, zero_division=0)
    cm = confusion_matrix(y_true, y_pred)
    return {"accuracy": acc, "precision": prec, "recall": rec, "f1": f1, "confusion_matrix": cm}

def print_report(name, report, label_encoder=None):
    print(f"=== {name} ===")
    print(f"Accuracy: {report['accuracy']:.4f}")
    print(f"Precision (macro): {report['precision']:.4f}")
    print(f"Recall (macro): {report['recall']:.4f}")
    print(f"F1 (macro): {report['f1']:.4f}")
    print("Confusion matrix shape:", report['confusion_matrix'].shape)
    print()

# %% [markdown]
# ## Implementación del Modelo

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier

# TF-IDF
tfidf = TfidfVectorizer(max_features=50000, ngram_range=(1,2), min_df=3)
X_train_tfidf = tfidf.fit_transform(X_train)
X_val_tfidf = tfidf.transform(X_val)
X_test_tfidf = tfidf.transform(X_test)

# XGBoost classifier (CPU settings). 
# Si luego ejecutas en GPU cambias tree_method='gpu_hist', predictor='gpu_predictor', gpu_id=0
xgb = XGBClassifier(
    objective='multi:softprob',
    num_class=n_classes,
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    tree_method='hist',   # 'hist' para CPU; cambiar a 'gpu_hist' en Colab GPU
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42,
    verbosity=1
)

# Entrenamiento con early stopping (usando validación)
start = time.time()
xgb.fit(
    X_train_tfidf, y_train,
    eval_set=[(X_val_tfidf, y_val)],
    verbose=True
)
elapsed = time.time() - start
print("Tiempo training XGBoost (s):", elapsed)

# Guardar artefactos
os.makedirs("artifacts", exist_ok=True)
joblib.dump(tfidf, "artifacts/tfidf_vectorizer.joblib")
xgb.save_model("artifacts/xgb_model.json")
# Out:
# c:\Users\TAWTOCA\anaconda3\envs\machine\lib\site-packages\xgboost\training.py:183: UserWarning: [21:33:33] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	validation_0-mlogloss:2.60419
# [1]	validation_0-mlogloss:2.30737
# [2]	validation_0-mlogloss:2.10351
# [3]	validation_0-mlogloss:1.94830
# [4]	validation_0-mlogloss:1.81214
# [5]	validation_0-mlogloss:1.70226
# [6]	validation_0-mlogloss:1.61337
# [7]	validation_0-mlogloss:1.53138
# [8]	validation_0-mlogloss:1.45995
# [9]	validation_0-mlogloss:1.39895
# [10]	validation_0-mlogloss:1.34058
# [11]	validation_0-mlogloss:1.28770
# [12]	validation_0-mlogloss:1.24344
# [13]	validation_0-mlogloss:1.19814
# [14]	validation_0-mlogloss:1.15771
# [15]	validation_0-mlogloss:1.12223
# [16]	validation_0-mlogloss:1.09101
# [17]	validation_0-mlogloss:1.05966
# [18]	validation_0-mlogloss:1.03338
# [19]	validation_0-mlogloss:1.00707
# [20]	validation_0-mlogloss:0.98388
# [21]	validation_0-mlogloss:0.96276
# [22]	validation_0-mlogloss:0.94330
# [23]	validation_0-mlogloss:0.92549
# [24]	validation_0-mlogloss:0.90526
# [25]	validation_0-mlogloss:0.88983
# [26]	validation_0-mlogloss:0.87708
# [27]	validation_0-mlogloss:0.86458
# [28]	validation_0-mlogloss:0.85290
# [29]	validation_0-mlogloss:0.84104
# [30]	validation_0-mlogloss:0.83059
# [31]	validation_0-mlogloss:0.82155
# [32]	validation_0-mlogloss:0.81212
# [33]	validation_0-mlogloss:0.80378
# [34]	validation_0-mlogloss:0.79419
# [35]	validation_0-mlogloss:0.78575
# [36]	validation_0-mlogloss:0.77852
# [37]	validation_0-mlogloss:0.77289
# [38]	validation_0-mlogloss:0.76604
# [39]	validation_0-mlogloss:0.75805
# [40]	validation_0-mlogloss:0.75366
# [41]	validation_0-mlogloss:0.74715
# [42]	validation_0-mlogloss:0.74259
# [43]	validation_0-mlogloss:0.73811
# [44]	validation_0-mlogloss:0.73331
# [45]	validation_0-mlogloss:0.72767
# [46]	validation_0-mlogloss:0.72431
# [47]	validation_0-mlogloss:0.72060
# [48]	validation_0-mlogloss:0.71737
# [49]	validation_0-mlogloss:0.71309
# [50]	validation_0-mlogloss:0.70955
# [51]	validation_0-mlogloss:0.70654
# [52]	validation_0-mlogloss:0.70378
# [53]	validation_0-mlogloss:0.70096
# [54]	validation_0-mlogloss:0.69868
# [55]	validation_0-mlogloss:0.69597
# [56]	validation_0-mlogloss:0.69358
# [57]	validation_0-mlogloss:0.69170
# [58]	validation_0-mlogloss:0.69053
# [59]	validation_0-mlogloss:0.68862
# [60]	validation_0-mlogloss:0.68621
# [61]	validation_0-mlogloss:0.68551
# [62]	validation_0-mlogloss:0.68358
# [63]	validation_0-mlogloss:0.68329
# [64]	validation_0-mlogloss:0.68148
# [65]	validation_0-mlogloss:0.68024
# [66]	validation_0-mlogloss:0.67926
# [67]	validation_0-mlogloss:0.67800
# [68]	validation_0-mlogloss:0.67785
# [69]	validation_0-mlogloss:0.67609
# [70]	validation_0-mlogloss:0.67516
# [71]	validation_0-mlogloss:0.67483
# [72]	validation_0-mlogloss:0.67407
# [73]	validation_0-mlogloss:0.67344
# [74]	validation_0-mlogloss:0.67284
# [75]	validation_0-mlogloss:0.67214
# [76]	validation_0-mlogloss:0.67276
# [77]	validation_0-mlogloss:0.67155
# [78]	validation_0-mlogloss:0.67076
# [79]	validation_0-mlogloss:0.67023
# [80]	validation_0-mlogloss:0.66975
# [81]	validation_0-mlogloss:0.66957
# [82]	validation_0-mlogloss:0.66876
# [83]	validation_0-mlogloss:0.66824
# [84]	validation_0-mlogloss:0.66777
# [85]	validation_0-mlogloss:0.66746
# [86]	validation_0-mlogloss:0.66670
# [87]	validation_0-mlogloss:0.66681
# [88]	validation_0-mlogloss:0.66684
# [89]	validation_0-mlogloss:0.66661
# [90]	validation_0-mlogloss:0.66726
# [91]	validation_0-mlogloss:0.66656
# [92]	validation_0-mlogloss:0.66665
# [93]	validation_0-mlogloss:0.66628
# [94]	validation_0-mlogloss:0.66591
# [95]	validation_0-mlogloss:0.66572
# [96]	validation_0-mlogloss:0.66545
# [97]	validation_0-mlogloss:0.66567
# [98]	validation_0-mlogloss:0.66563
# [99]	validation_0-mlogloss:0.66551
# [100]	validation_0-mlogloss:0.66559
# [101]	validation_0-mlogloss:0.66516
# [102]	validation_0-mlogloss:0.66493
# [103]	validation_0-mlogloss:0.66406
# [104]	validation_0-mlogloss:0.66433
# [105]	validation_0-mlogloss:0.66504
# [106]	validation_0-mlogloss:0.66466
# [107]	validation_0-mlogloss:0.66452
# [108]	validation_0-mlogloss:0.66389
# [109]	validation_0-mlogloss:0.66392
# [110]	validation_0-mlogloss:0.66388
# [111]	validation_0-mlogloss:0.66398
# [112]	validation_0-mlogloss:0.66366
# [113]	validation_0-mlogloss:0.66380
# [114]	validation_0-mlogloss:0.66359
# [115]	validation_0-mlogloss:0.66410
# [116]	validation_0-mlogloss:0.66431
# [117]	validation_0-mlogloss:0.66462
# [118]	validation_0-mlogloss:0.66410
# [119]	validation_0-mlogloss:0.66397
# [120]	validation_0-mlogloss:0.66404
# [121]	validation_0-mlogloss:0.66396
# [122]	validation_0-mlogloss:0.66413
# [123]	validation_0-mlogloss:0.66455
# [124]	validation_0-mlogloss:0.66412
# [125]	validation_0-mlogloss:0.66436
# [126]	validation_0-mlogloss:0.66435
# [127]	validation_0-mlogloss:0.66486
# [128]	validation_0-mlogloss:0.66533
# [129]	validation_0-mlogloss:0.66537
# [130]	validation_0-mlogloss:0.66519
# [131]	validation_0-mlogloss:0.66522
# [132]	validation_0-mlogloss:0.66520
# [133]	validation_0-mlogloss:0.66556
# [134]	validation_0-mlogloss:0.66561
# [135]	validation_0-mlogloss:0.66557
# [136]	validation_0-mlogloss:0.66565
# [137]	validation_0-mlogloss:0.66565
# [138]	validation_0-mlogloss:0.66605
# [139]	validation_0-mlogloss:0.66596
# [140]	validation_0-mlogloss:0.66632
# [141]	validation_0-mlogloss:0.66620
# [142]	validation_0-mlogloss:0.66650
# [143]	validation_0-mlogloss:0.66694
# [144]	validation_0-mlogloss:0.66711
# [145]	validation_0-mlogloss:0.66742
# [146]	validation_0-mlogloss:0.66728
# [147]	validation_0-mlogloss:0.66723
# [148]	validation_0-mlogloss:0.66741
# [149]	validation_0-mlogloss:0.66749
# [150]	validation_0-mlogloss:0.66785
# [151]	validation_0-mlogloss:0.66804
# [152]	validation_0-mlogloss:0.66842
# [153]	validation_0-mlogloss:0.66845
# [154]	validation_0-mlogloss:0.66852
# [155]	validation_0-mlogloss:0.66836
# [156]	validation_0-mlogloss:0.66844
# [157]	validation_0-mlogloss:0.66852
# [158]	validation_0-mlogloss:0.66879
# [159]	validation_0-mlogloss:0.66883
# [160]	validation_0-mlogloss:0.66927
# [161]	validation_0-mlogloss:0.66942
# [162]	validation_0-mlogloss:0.66934
# [163]	validation_0-mlogloss:0.66954
# [164]	validation_0-mlogloss:0.66962
# [165]	validation_0-mlogloss:0.66965
# [166]	validation_0-mlogloss:0.66980
# [167]	validation_0-mlogloss:0.67026
# [168]	validation_0-mlogloss:0.67064
# [169]	validation_0-mlogloss:0.67054
# [170]	validation_0-mlogloss:0.67086
# [171]	validation_0-mlogloss:0.67154
# [172]	validation_0-mlogloss:0.67176
# [173]	validation_0-mlogloss:0.67178
# [174]	validation_0-mlogloss:0.67177
# [175]	validation_0-mlogloss:0.67198
# [176]	validation_0-mlogloss:0.67244
# [177]	validation_0-mlogloss:0.67240
# [178]	validation_0-mlogloss:0.67243
# [179]	validation_0-mlogloss:0.67271
# [180]	validation_0-mlogloss:0.67267
# [181]	validation_0-mlogloss:0.67287
# [182]	validation_0-mlogloss:0.67281
# [183]	validation_0-mlogloss:0.67316
# [184]	validation_0-mlogloss:0.67322
# [185]	validation_0-mlogloss:0.67330
# [186]	validation_0-mlogloss:0.67329
# [187]	validation_0-mlogloss:0.67329
# [188]	validation_0-mlogloss:0.67351
# [189]	validation_0-mlogloss:0.67379
# [190]	validation_0-mlogloss:0.67406
# [191]	validation_0-mlogloss:0.67400
# [192]	validation_0-mlogloss:0.67432
# [193]	validation_0-mlogloss:0.67430
# [194]	validation_0-mlogloss:0.67435
# [195]	validation_0-mlogloss:0.67430
# [196]	validation_0-mlogloss:0.67431
# [197]	validation_0-mlogloss:0.67419
# [198]	validation_0-mlogloss:0.67446
# [199]	validation_0-mlogloss:0.67434
# [200]	validation_0-mlogloss:0.67467
# [201]	validation_0-mlogloss:0.67479
# [202]	validation_0-mlogloss:0.67475
# [203]	validation_0-mlogloss:0.67499
# [204]	validation_0-mlogloss:0.67506
# [205]	validation_0-mlogloss:0.67499
# [206]	validation_0-mlogloss:0.67510
# [207]	validation_0-mlogloss:0.67536
# [208]	validation_0-mlogloss:0.67522
# [209]	validation_0-mlogloss:0.67528
# [210]	validation_0-mlogloss:0.67538
# [211]	validation_0-mlogloss:0.67544
# [212]	validation_0-mlogloss:0.67575
# [213]	validation_0-mlogloss:0.67587
# [214]	validation_0-mlogloss:0.67605
# [215]	validation_0-mlogloss:0.67587
# [216]	validation_0-mlogloss:0.67600
# [217]	validation_0-mlogloss:0.67618
# [218]	validation_0-mlogloss:0.67614
# [219]	validation_0-mlogloss:0.67646
# [220]	validation_0-mlogloss:0.67657
# [221]	validation_0-mlogloss:0.67650
# [222]	validation_0-mlogloss:0.67644
# [223]	validation_0-mlogloss:0.67646
# [224]	validation_0-mlogloss:0.67655
# [225]	validation_0-mlogloss:0.67661
# [226]	validation_0-mlogloss:0.67679
# [227]	validation_0-mlogloss:0.67673
# [228]	validation_0-mlogloss:0.67685
# [229]	validation_0-mlogloss:0.67697
# [230]	validation_0-mlogloss:0.67710
# [231]	validation_0-mlogloss:0.67742
# [232]	validation_0-mlogloss:0.67761
# [233]	validation_0-mlogloss:0.67803
# [234]	validation_0-mlogloss:0.67808
# [235]	validation_0-mlogloss:0.67782
# [236]	validation_0-mlogloss:0.67796
# [237]	validation_0-mlogloss:0.67808
# [238]	validation_0-mlogloss:0.67813
# [239]	validation_0-mlogloss:0.67842
# [240]	validation_0-mlogloss:0.67853
# [241]	validation_0-mlogloss:0.67855
# [242]	validation_0-mlogloss:0.67877
# [243]	validation_0-mlogloss:0.67876
# [244]	validation_0-mlogloss:0.67865
# [245]	validation_0-mlogloss:0.67904
# [246]	validation_0-mlogloss:0.67908
# [247]	validation_0-mlogloss:0.67932
# [248]	validation_0-mlogloss:0.67947
# [249]	validation_0-mlogloss:0.67949
# [250]	validation_0-mlogloss:0.67942
# [251]	validation_0-mlogloss:0.67936
# [252]	validation_0-mlogloss:0.67956
# [253]	validation_0-mlogloss:0.67962
# [254]	validation_0-mlogloss:0.67968
# [255]	validation_0-mlogloss:0.67989
# [256]	validation_0-mlogloss:0.68005
# [257]	validation_0-mlogloss:0.68013
# [258]	validation_0-mlogloss:0.68038
# [259]	validation_0-mlogloss:0.68026
# [260]	validation_0-mlogloss:0.68047
# [261]	validation_0-mlogloss:0.68057
# [262]	validation_0-mlogloss:0.68063
# [263]	validation_0-mlogloss:0.68064
# [264]	validation_0-mlogloss:0.68078
# [265]	validation_0-mlogloss:0.68096
# [266]	validation_0-mlogloss:0.68098
# [267]	validation_0-mlogloss:0.68108
# [268]	validation_0-mlogloss:0.68117
# [269]	validation_0-mlogloss:0.68120
# [270]	validation_0-mlogloss:0.68123
# [271]	validation_0-mlogloss:0.68135
# [272]	validation_0-mlogloss:0.68136
# [273]	validation_0-mlogloss:0.68148
# [274]	validation_0-mlogloss:0.68164
# [275]	validation_0-mlogloss:0.68181
# [276]	validation_0-mlogloss:0.68174
# [277]	validation_0-mlogloss:0.68174
# [278]	validation_0-mlogloss:0.68184
# [279]	validation_0-mlogloss:0.68190
# [280]	validation_0-mlogloss:0.68193
# [281]	validation_0-mlogloss:0.68191
# [282]	validation_0-mlogloss:0.68204
# [283]	validation_0-mlogloss:0.68223
# [284]	validation_0-mlogloss:0.68219
# [285]	validation_0-mlogloss:0.68237
# [286]	validation_0-mlogloss:0.68249
# [287]	validation_0-mlogloss:0.68284
# [288]	validation_0-mlogloss:0.68279
# [289]	validation_0-mlogloss:0.68286
# [290]	validation_0-mlogloss:0.68273
# [291]	validation_0-mlogloss:0.68273
# [292]	validation_0-mlogloss:0.68271
# [293]	validation_0-mlogloss:0.68274
# [294]	validation_0-mlogloss:0.68273
# [295]	validation_0-mlogloss:0.68287
# [296]	validation_0-mlogloss:0.68315
# [297]	validation_0-mlogloss:0.68322
# [298]	validation_0-mlogloss:0.68330
# [299]	validation_0-mlogloss:0.68361
# Tiempo training XGBoost (s): 610.4147791862488

# %%
# Predicciones
y_val_pred = xgb.predict(X_val_tfidf)
y_test_pred = xgb.predict(X_test_tfidf)

# Reportes
rep_val = classification_report_multi(y_val, y_val_pred)
rep_test = classification_report_multi(y_test, y_test_pred)

print_report("XGBoost VALIDATION", rep_val)
print_report("XGBoost TEST", rep_test)

# Matriz de confusión (test)
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
sns.heatmap(rep_test['confusion_matrix'], annot=False, fmt='d', cmap='Blues')
plt.title('Confusion matrix - XGBoost (test)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# ROC-AUC multiclasificación (one-vs-rest) - requiere probabilidades y binarizado
y_test_proba = xgb.predict_proba(X_test_tfidf)
y_test_binarized = label_binarize(y_test, classes=np.arange(n_classes))

try:
    roc_auc = roc_auc_score(y_test_binarized, y_test_proba, average='macro', multi_class='ovr')
    print("ROC-AUC (macro, ovr):", roc_auc)
except Exception as e:
    print("ROC-AUC no pudo calcularse:", e)
# Out:
# === XGBoost VALIDATION ===
# Accuracy: 0.7962
# Precision (macro): 0.7639
# Recall (macro): 0.7609
# F1 (macro): 0.7556
# Confusion matrix shape: (24, 24)
#
# === XGBoost TEST ===
# Accuracy: 0.7694
# Precision (macro): 0.7969
# Recall (macro): 0.7286
# F1 (macro): 0.7351
# Confusion matrix shape: (24, 24)
# ROC-AUC (macro, ovr): 0.981145858897238
